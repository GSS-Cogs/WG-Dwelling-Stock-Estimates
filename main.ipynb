# %% [markdown]
# Dwelling stock estimates by local authority and tenure

# %%
from gssutils import *

# %%
data = pd.read_json('http://open.statswales.gov.wales/en-gb/dataset/hous0501')

# %%
data.head()
# Out:
#                                       odata.metadata  \
# 0  http://open.statswales.gov.wales/en-gb/dataset...
# 1  http://open.statswales.gov.wales/en-gb/dataset...
# 2  http://open.statswales.gov.wales/en-gb/dataset...
# 3  http://open.statswales.gov.wales/en-gb/dataset...
# 4  http://open.statswales.gov.wales/en-gb/dataset...
#
#                                                value  \
# 0  {'Data': 4664.0, 'Area_Code': '512', 'Area_Ite...
# 1  {'Data': 7308.0, 'Area_Code': '514', 'Area_Ite...
# 2  {'Data': 4268.0, 'Area_Code': '516', 'Area_Ite...
# 3  {'Data': 4141.0, 'Area_Code': '518', 'Area_Ite...
# 4  {'Data': 8534.0, 'Area_Code': '520', 'Area_Ite...
#
#                                       odata.nextLink
# 0  http://open.statswales.gov.wales/en-gb/dataset...
# 1  http://open.statswales.gov.wales/en-gb/dataset...
# 2  http://open.statswales.gov.wales/en-gb/dataset...
# 3  http://open.statswales.gov.wales/en-gb/dataset...
# 4  http://open.statswales.gov.wales/en-gb/dataset...

# %%
data.head(1)['value'][0]
# Out:
# {'Area_Code': '512',
#  'Area_ItemName_ENG': 'Isle of Anglesey',
#  'Area_ItemNotes_ENG': '',
#  'Area_SortOrder': '2',
#  'Data': 4664.0,
#  'PartitionKey': '',
#  'RowKey': '0000000000000000',
#  'Tenure_Code': '1',
#  'Tenure_ItemName_ENG': 'Local Authority (Number)',
#  'Tenure_ItemNotes_ENG': 'Prior to 2008-09 data are from the Housing Revenue Account Subsidy (HRAS) second advance form. &#10;For 2008-09 onwards, data are from the annual Social Housing Stock return from local authorities.&#10;&#10;Data has been affected by the large scale voluntary stock transfers of local authority stock to registered social landlords&#10;&#10;Excludes intermediate and other tenures not at social rents',
#  'Tenure_SortOrder': '1',
#  'Year_Code': '200001',
#  'Year_ItemName_ENG': '2000-01',
#  'Year_SortOrder': '5'}

# %%
table = pd.DataFrame()
for row in data.iterrows():
    da = row[1]['value']
    temp =  pd.DataFrame(da, index = [0])  
    table = pd.concat([table, temp])

# %%
table.reset_index(inplace = True)

# %%
table.drop(['index','Area_SortOrder','Area_Code','Area_ItemNotes_ENG',
             'Year_Code',            
             'Year_SortOrder',
             'Tenure_Code',
             'Tenure_SortOrder',
             'Tenure_ItemNotes_ENG',
             'RowKey',
             'PartitionKey'], axis = 1, inplace =True)

# %%
table.columns.values[0] = 'Value'
table.columns.values[1] = 'Geography'
table.columns.values[2] = 'Period'
table.columns.values[3] = 'Tenure'

# %%
table = table[['Geography','Period','Tenure','Value']]

# %%
table['Unit'] = 'dwellings'
table['Measure Type'] = 'Count'

# %%
table['Period'] = 'gregorian-interval/' + table['Period'].astype(str).str[0:4]+ '-03-31T00:00:00/P1Y'

# %%
table['Tenure'] = table['Tenure'].map(
    lambda x: {
        'Local Authority (Number)' : 'local-authority', 
        'Registered Social Landlord (Number)' : 'registered-social-landlord' ,
       'Owner occupied/Privately rented (Number)' : 'owner-occupied-privately-rented'
        }.get(x, x))

# %%
table['Geography'] = table['Geography'].map(
    lambda x: {
        'Blaenau Gwent':'W06000019',
        'Bridgend':'W06000013',
        'Caerphilly':'W06000018',
        'Cardiff':'W06000015',
        'Carmarthenshire':'W06000010',
        'Ceredigion':'W06000008',
        'Conwy':'W06000003',
        'Denbighshire':'W06000004',
        'Flintshire':'W06000005',
        'Gwynedd':'W06000002',
        'Isle of Anglesey':'W06000001',
        'Merthyr Tydfil':'W06000024',
        'Monmouthshire':'W06000021',
        'Neath Port Talbot':'W06000012',
        'Newport':'W06000022',
        'Pembrokeshire':'W06000009',
        'Powys':'W06000023',
        'Rhondda Cynon Taf':'W06000016',
        'Swansea':'W06000011',
        'Torfaen':'W06000020',
        'Vale of Glamorgan':'W06000014',
        'Wales':'W92000004',
        'Wrexham':'W06000006'
        }.get(x, x))

# %%
table['Value'] = table['Value'].apply(lambda x: pd.to_numeric(x, downcast='integer'))
table['Value'] = table['Value'].astype(int)

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

table.to_csv(destinationFolder / ('observations.csv'), index = False)

# %%
table
# Out:
#      Geography                                      Period  \
# 0    W06000001  gregorian-interval/2000-03-31T00:00:00/P1Y
# 1    W06000002  gregorian-interval/2000-03-31T00:00:00/P1Y
# 2    W06000003  gregorian-interval/2000-03-31T00:00:00/P1Y
# 3    W06000004  gregorian-interval/2000-03-31T00:00:00/P1Y
# 4    W06000005  gregorian-interval/2000-03-31T00:00:00/P1Y
# 5    W06000006  gregorian-interval/2000-03-31T00:00:00/P1Y
# 6    W06000023  gregorian-interval/2000-03-31T00:00:00/P1Y
# 7    W06000008  gregorian-interval/2000-03-31T00:00:00/P1Y
# 8    W06000009  gregorian-interval/2000-03-31T00:00:00/P1Y
# 9    W06000010  gregorian-interval/2000-03-31T00:00:00/P1Y
# 10   W06000011  gregorian-interval/2000-03-31T00:00:00/P1Y
# 11   W06000012  gregorian-interval/2000-03-31T00:00:00/P1Y
# 12   W06000013  gregorian-interval/2000-03-31T00:00:00/P1Y
# 13   W06000014  gregorian-interval/2000-03-31T00:00:00/P1Y
# 14   W06000016  gregorian-interval/2000-03-31T00:00:00/P1Y
# ...
